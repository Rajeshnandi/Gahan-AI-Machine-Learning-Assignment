# %% [markdown]
# ## Rajesh Nandi
# ## Mail id : rajeshnandi100@gmail.com

# %% [markdown]
# ## Import ZIP File ##

# %%
import pandas as pd
import numpy as np

# %%
from zipfile import ZipFile
file_name = "data2.zip"

# %%
z= ZipFile(file_name)
z
# Out:
# <zipfile.ZipFile filename='data2.zip' mode='r'>

# %%
e=z.namelist()

# %%
e
# Out:
# ['data2/',
#  'data2/S/',
#  'data2/S/S099.txt',
#  'data2/S/S098.txt',
#  'data2/S/S097.txt',
#  'data2/S/S096.txt',
#  'data2/S/S095.txt',
#  'data2/S/S094.txt',
#  'data2/S/S093.txt',
#  'data2/S/S092.txt',
#  'data2/S/S091.txt',
#  'data2/S/S090.txt',
#  'data2/S/S089.txt',
#  'data2/S/S088.txt',
#  'data2/S/S087.txt',
#  'data2/S/S086.txt',
#  'data2/S/S085.txt',
#  'data2/S/S084.txt',
#  'data2/S/S083.txt',
#  'data2/S/S082.txt',
#  'data2/S/S081.txt',
#  'data2/S/S080.txt',
#  'data2/S/S079.txt',
#  'data2/S/S078.txt',
#  'data2/S/S077.txt',
#  'data2/S/S076.txt',
#  'data2/S/S075.txt',
#  'data2/S/S074.txt',
#  'data2/S/S073.txt',
#  'data2/S/S072.txt',
#  'data2/S/S071.txt',
#  'data2/S/S070.txt',
#  'data2/S/S069.txt',
#  'data2/S/S068.txt',
#  'data2/S/S067.txt',
#  'data2/S/S066.txt',
#  'data2/S/S065.txt',
#  'data2/S/S064.txt',
#  'data2/S/S063.txt',
#  'data2/S/S062.txt',
#  'data2/S/S061.txt',
#  'data2/S/S060.txt',
#  'data2/S/S059.txt',
#  'data2/S/S058.txt',
# ...

# %%
type(e)
# Out:
# list

# %% [markdown]
# ## Extract all txt file from the ZIP File  First Folder using Pandas and Numpy

# %%
import zipfile
zf = zipfile.ZipFile('data2.zip')
df_zip1 = pd.read_csv(zf.open('data2/S/S001.txt'),names=["A"])
df_zip1
# Out:
#         A
# 0     100
# 1     124
# 2     153
# 3     185
# 4     210
# ...   ...
# 4092    7
# 4093   26
# 4094   57
# 4095   95
# 4096  462
#
# [4097 rows x 1 columns]

# %%
import zipfile
zf = zipfile.ZipFile('data2.zip')
df_zip2 = pd.read_csv(zf.open('data2/S/S002.txt'),names=["B"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip3 = pd.read_csv(zf.open('data2/S/S003.txt'),names=["C"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip4 = pd.read_csv(zf.open('data2/S/S004.txt'),names=["D"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip5 = pd.read_csv(zf.open('data2/S/S005.txt'),names=["E"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip6 = pd.read_csv(zf.open('data2/S/S006.txt'),names=["F"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip7 = pd.read_csv(zf.open('data2/S/S007.txt'),names=["G"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip8 = pd.read_csv(zf.open('data2/S/S008.txt'),names=["H"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip9 = pd.read_csv(zf.open('data2/S/S009.txt'),names=["I"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip10 = pd.read_csv(zf.open('data2/S/S100.txt'),names=["J"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip11 = pd.read_csv(zf.open('data2/S/S020.txt'),names=["K"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip12 = pd.read_csv(zf.open('data2/S/S021.txt'),names=["L"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip13 = pd.read_csv(zf.open('data2/S/S022.txt'),names=["M"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip14 = pd.read_csv(zf.open('data2/S/S025.txt'),names=["N"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip15 = pd.read_csv(zf.open('data2/S/S026.txt'),names=["N"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip16 = pd.read_csv(zf.open('data2/S/S027.txt'),names=["O"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip17 = pd.read_csv(zf.open('data2/S/S028.txt'),names=["P"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip18 = pd.read_csv(zf.open('data2/S/S029.txt'),names=["Q"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip19 = pd.read_csv(zf.open('data2/S/S030.txt'),names=["R"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip20 = pd.read_csv(zf.open('data2/S/S031.txt'),names=["S"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip21 = pd.read_csv(zf.open('data2/S/S032.txt'),names=["T"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip22 = pd.read_csv(zf.open('data2/S/S033.txt'),names=["U"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip23 = pd.read_csv(zf.open('data2/S/S034.txt'),names=["V"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip24 = pd.read_csv(zf.open('data2/S/S035.txt'),names=["W"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip25 = pd.read_csv(zf.open('data2/S/S036.txt'),names=["X"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip26 = pd.read_csv(zf.open('data2/S/S037.txt'),names=["Y"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip27 = pd.read_csv(zf.open('data2/S/S038.txt'),names=["Z"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip28 = pd.read_csv(zf.open('data2/S/S039.txt'),names=["A2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip29 = pd.read_csv(zf.open('data2/S/S040.txt'),names=["B2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip30 = pd.read_csv(zf.open('data2/S/S041.txt'),names=["C2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip31 = pd.read_csv(zf.open('data2/S/S042.txt'),names=["D2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip32 = pd.read_csv(zf.open('data2/S/S043.txt'),names=["E2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip33 = pd.read_csv(zf.open('data2/S/S044.txt'),names=["F2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip35 = pd.read_csv(zf.open('data2/S/S045.txt'),names=["G2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip36 = pd.read_csv(zf.open('data2/S/S046.txt'),names=["H2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip37 = pd.read_csv(zf.open('data2/S/S047.txt'),names=["I2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip38 = pd.read_csv(zf.open('data2/S/S048.txt'),names=["J2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip39 = pd.read_csv(zf.open('data2/S/S049.txt'),names=["K2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip40 = pd.read_csv(zf.open('data2/S/S050.txt'),names=["L2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip41 = pd.read_csv(zf.open('data2/S/S051.txt'),names=["M2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip42 = pd.read_csv(zf.open('data2/S/S052.txt'),names=["N2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip43 = pd.read_csv(zf.open('data2/S/S053.txt'),names=["O2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip44 = pd.read_csv(zf.open('data2/S/S054.txt'),names=["P2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip45 = pd.read_csv(zf.open('data2/S/S055.txt'),names=["Q2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip46 = pd.read_csv(zf.open('data2/S/S056.txt'),names=["R2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip47 = pd.read_csv(zf.open('data2/S/S057.txt'),names=["S2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip48 = pd.read_csv(zf.open('data2/S/S058.txt'),names=["T2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip49 = pd.read_csv(zf.open('data2/S/S059.txt'),names=["U2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip50 = pd.read_csv(zf.open('data2/S/S060.txt'),names=["V2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip51 = pd.read_csv(zf.open('data2/S/S061.txt'),names=["W2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip52 = pd.read_csv(zf.open('data2/S/S062.txt'),names=["X2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip53 = pd.read_csv(zf.open('data2/S/S063.txt'),names=["Y2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip54 = pd.read_csv(zf.open('data2/S/S064.txt'),names=["Z2"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip55 = pd.read_csv(zf.open('data2/S/S065.txt'),names=["A3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip56 = pd.read_csv(zf.open('data2/S/S066.txt'),names=["B3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip57 = pd.read_csv(zf.open('data2/S/S067.txt'),names=["C3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip58 = pd.read_csv(zf.open('data2/S/S068.txt'),names=["D3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip59 = pd.read_csv(zf.open('data2/S/S069.txt'),names=["E3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip60 = pd.read_csv(zf.open('data2/S/S070.txt'),names=["F3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip61 = pd.read_csv(zf.open('data2/S/S071.txt'),names=["G3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip62 = pd.read_csv(zf.open('data2/S/S072.txt'),names=["H3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip63 = pd.read_csv(zf.open('data2/S/S073.txt'),names=["I3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip64 = pd.read_csv(zf.open('data2/S/S074.txt'),names=["J3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip65 = pd.read_csv(zf.open('data2/S/S075.txt'),names=["K3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip66 = pd.read_csv(zf.open('data2/S/S076.txt'),names=["L3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip67 = pd.read_csv(zf.open('data2/S/S077.txt'),names=["M3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip68 = pd.read_csv(zf.open('data2/S/S078.txt'),names=["N3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip69 = pd.read_csv(zf.open('data2/S/S079.txt'),names=["O3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip70 = pd.read_csv(zf.open('data2/S/S080.txt'),names=["P3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip71 = pd.read_csv(zf.open('data2/S/S081.txt'),names=["Q3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip72 = pd.read_csv(zf.open('data2/S/S082.txt'),names=["R3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip73 = pd.read_csv(zf.open('data2/S/S083.txt'),names=["S3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip74 = pd.read_csv(zf.open('data2/S/S084.txt'),names=["T3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip75 = pd.read_csv(zf.open('data2/S/S085.txt'),names=["U3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip76 = pd.read_csv(zf.open('data2/S/S086.txt'),names=["V3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip77 = pd.read_csv(zf.open('data2/S/S087.txt'),names=["W3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip78 = pd.read_csv(zf.open('data2/S/S088.txt'),names=["X3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip79 = pd.read_csv(zf.open('data2/S/S089.txt'),names=["Y3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip80 = pd.read_csv(zf.open('data2/S/S090.txt'),names=["Z3"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip81 = pd.read_csv(zf.open('data2/S/S091.txt'),names=["A4"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip82 = pd.read_csv(zf.open('data2/S/S092.txt'),names=["B4"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip83 = pd.read_csv(zf.open('data2/S/S093.txt'),names=["C4"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip84 = pd.read_csv(zf.open('data2/S/S094.txt'),names=["D4"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip85 = pd.read_csv(zf.open('data2/S/S095.txt'),names=["E4"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip86 = pd.read_csv(zf.open('data2/S/S096.txt'),names=["F4"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip87 = pd.read_csv(zf.open('data2/S/S097.txt'),names=["G4"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip88 = pd.read_csv(zf.open('data2/S/S098.txt'),names=["H4"])

# %%
zf = zipfile.ZipFile('data2.zip')
df_zip89 = pd.read_csv(zf.open('data2/S/S099.txt'),names=["I4"])
df_zip89
# Out:
#        I4
# 0    -476
# 1    -518
# 2    -521
# 3    -362
# 4     -68
# ...   ...
# 4092  224
# 4093  299
# 4094  246
# 4095  556
# 4096  276
#
# [4097 rows x 1 columns]

# %% [markdown]
# ## Convert txt File to a DataFrame

# %%
txt_concat1=pd.concat([df_zip1,df_zip2,df_zip3,df_zip4,df_zip5,df_zip6,df_zip7,df_zip8,df_zip9,df_zip10,df_zip11,df_zip12,df_zip13,df_zip14,df_zip15,df_zip16,df_zip17,df_zip18,df_zip19,df_zip20,df_zip21,df_zip22,df_zip23,df_zip24,df_zip25,df_zip26,df_zip27,df_zip28,df_zip29,df_zip30,df_zip31,df_zip32,df_zip33,df_zip35,df_zip36,df_zip37,df_zip38,df_zip39,df_zip40,df_zip41,df_zip42,df_zip43,df_zip44,df_zip45,df_zip46,df_zip47,df_zip48,df_zip49,df_zip50,df_zip51,df_zip52,df_zip53,df_zip54,df_zip55,df_zip56,df_zip57,df_zip58,df_zip59,df_zip60,df_zip61,df_zip62,df_zip63,df_zip64,df_zip65,df_zip66,df_zip67,df_zip68,df_zip69,df_zip70,df_zip71,df_zip72,df_zip73,df_zip74,df_zip75,df_zip76,df_zip77,df_zip78,df_zip79,df_zip80,df_zip81,df_zip82,df_zip83,df_zip84,df_zip85,df_zip86,df_zip87,df_zip88,df_zip89],axis=1)
txt_concat1
# Out:
#         A    B    C    D    E    F    G    H    I    J  ...   Z3   A4   B4  \
# 0     100  340 -310   84  343  -88  176  661 -377   23  ...  134 -129  -26
# 1     124  353   93   75  311 -115  186  721 -379  144  ...  390 -309    1
# 2     153  400  494   21  284 -140  189  702 -396  228  ...  446 -432   29
# 3     185  470  789  -68  274 -159  198  628 -448  260  ...  329 -412   41
# 4     210  538  798 -138  260 -164  205  519 -476  255  ...   49 -278   33
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4092    7  829 -735 -234  515  153  100    7  -93 -272  ... -104  -44 -205
# 4093   26  722 -847 -238  527  150   98    5  -82 -272  ... -189   95 -209
# 4094   57  512 -721 -209  480  146  101   12  -89 -155  ... -153   12 -207
# 4095   95  130 -491 -165  397  140   99   29 -132    6  ...  -62 -254 -210
# 4096  462  196  910 -212  217  191 -554 -211 -279 -221  ...   72  -57 -107
#
#         C4   D4   E4   F4   G4   H4   I4
# ...

# %%
dataset1=pd.DataFrame(txt_concat1)
dataset1
# Out:
#         A    B    C    D    E    F    G    H    I    J  ...   Z3   A4   B4  \
# 0     100  340 -310   84  343  -88  176  661 -377   23  ...  134 -129  -26
# 1     124  353   93   75  311 -115  186  721 -379  144  ...  390 -309    1
# 2     153  400  494   21  284 -140  189  702 -396  228  ...  446 -432   29
# 3     185  470  789  -68  274 -159  198  628 -448  260  ...  329 -412   41
# 4     210  538  798 -138  260 -164  205  519 -476  255  ...   49 -278   33
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4092    7  829 -735 -234  515  153  100    7  -93 -272  ... -104  -44 -205
# 4093   26  722 -847 -238  527  150   98    5  -82 -272  ... -189   95 -209
# 4094   57  512 -721 -209  480  146  101   12  -89 -155  ... -153   12 -207
# 4095   95  130 -491 -165  397  140   99   29 -132    6  ...  -62 -254 -210
# 4096  462  196  910 -212  217  191 -554 -211 -279 -221  ...   72  -57 -107
#
#         C4   D4   E4   F4   G4   H4   I4
# ...

# %%
dataset1.isnull().sum()
# Out:
# A     0
# B     0
# C     0
# D     0
# E     0
#      ..
# E4    0
# F4    0
# G4    0
# H4    0
# I4    0
# Length: 88, dtype: int64

# %%
type(txt_concat1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Extract all txt file from the ZIP File Second Folder using Pandas and Numpy

# %%
file = zipfile.ZipFile('data2.zip')
file1 = pd.read_csv(zf.open('data2/O/O011.txt'),names=["A"])
file1
# Out:
#         A
# 0    -159
# 1    -176
# 2    -174
# 3    -145
# 4    -101
# ...   ...
# 4092  -62
# 4093 -100
# 4094 -108
# 4095  -97
# 4096 -110
#
# [4097 rows x 1 columns]

# %%
file = zipfile.ZipFile('data2.zip')
file2 = pd.read_csv(zf.open('data2/O/O012.txt'),names=["B"])

# %%
file = zipfile.ZipFile('data2.zip')
file3 = pd.read_csv(zf.open('data2/O/O013.txt'),names=["C"])

# %%
file = zipfile.ZipFile('data2.zip')
file4 = pd.read_csv(zf.open('data2/O/O014.txt'),names=["D"])

# %%
file = zipfile.ZipFile('data2.zip')
file5 = pd.read_csv(zf.open('data2/O/O015.txt'),names=["E"])

# %%
file = zipfile.ZipFile('data2.zip')
file6 = pd.read_csv(zf.open('data2/O/O016.txt'),names=["F"])

# %%
file = zipfile.ZipFile('data2.zip')
file7 = pd.read_csv(zf.open('data2/O/O017.txt'),names=["G"])

# %%
file = zipfile.ZipFile('data2.zip')
file8 = pd.read_csv(zf.open('data2/O/O018.txt'),names=["H"])

# %%
file = zipfile.ZipFile('data2.zip')
file9 = pd.read_csv(zf.open('data2/O/O019.txt'),names=["I"])

# %%
file = zipfile.ZipFile('data2.zip')
file10 = pd.read_csv(zf.open('data2/O/O020.txt'),names=["J"])

# %%
file = zipfile.ZipFile('data2.zip')
file11 = pd.read_csv(zf.open('data2/O/O021.txt'),names=["K"])

# %%
file = zipfile.ZipFile('data2.zip')
file12 = pd.read_csv(zf.open('data2/O/O022.txt'),names=["L"])

# %%
file = zipfile.ZipFile('data2.zip')
file13 = pd.read_csv(zf.open('data2/O/O023.txt'),names=["M"])

# %%
file = zipfile.ZipFile('data2.zip')
file14 = pd.read_csv(zf.open('data2/O/O026.txt'),names=["N"])

# %%
file = zipfile.ZipFile('data2.zip')
file15 = pd.read_csv(zf.open('data2/O/O027.txt'),names=["O"])

# %%
file = zipfile.ZipFile('data2.zip')
file16 = pd.read_csv(zf.open('data2/O/O028.txt'),names=["P"])

# %%
file = zipfile.ZipFile('data2.zip')
file17 = pd.read_csv(zf.open('data2/O/O029.txt'),names=["Q"])

# %%
file = zipfile.ZipFile('data2.zip')
file18 = pd.read_csv(zf.open('data2/O/O030.txt'),names=["R"])

# %%
file = zipfile.ZipFile('data2.zip')
file19 = pd.read_csv(zf.open('data2/O/O031.txt'),names=["S"])

# %%
file = zipfile.ZipFile('data2.zip')
file20 = pd.read_csv(zf.open('data2/O/O032.txt'),names=["T"])

# %%
file = zipfile.ZipFile('data2.zip')
file21 = pd.read_csv(zf.open('data2/O/O033.txt'),names=["U"])

# %%
file = zipfile.ZipFile('data2.zip')
file22 = pd.read_csv(zf.open('data2/O/O034.txt'),names=["V"])

# %%
file = zipfile.ZipFile('data2.zip')
file23 = pd.read_csv(zf.open('data2/O/O035.txt'),names=["W"])

# %%
file = zipfile.ZipFile('data2.zip')
file24 = pd.read_csv(zf.open('data2/O/O036.txt'),names=["X"])

# %%
file = zipfile.ZipFile('data2.zip')
file25 = pd.read_csv(zf.open('data2/O/O037.txt'),names=["Y"])

# %%
file = zipfile.ZipFile('data2.zip')
file26 = pd.read_csv(zf.open('data2/O/O038.txt'),names=["Z"])

# %%
file = zipfile.ZipFile('data2.zip')
file27 = pd.read_csv(zf.open('data2/O/O039.txt'),names=["A2"])

# %%
file = zipfile.ZipFile('data2.zip')
file28 = pd.read_csv(zf.open('data2/O/O040.txt'),names=["B2"])

# %%
file = zipfile.ZipFile('data2.zip')
file29 = pd.read_csv(zf.open('data2/O/O041.txt'),names=["C2"])

# %%
file = zipfile.ZipFile('data2.zip')
file30 = pd.read_csv(zf.open('data2/O/O042.txt'),names=["D2"])

# %%
file = zipfile.ZipFile('data2.zip')
file31 = pd.read_csv(zf.open('data2/O/O043.txt'),names=["E2"])

# %%
file = zipfile.ZipFile('data2.zip')
file32 = pd.read_csv(zf.open('data2/O/O044.txt'),names=["F2"])

# %%
file = zipfile.ZipFile('data2.zip')
file33 = pd.read_csv(zf.open('data2/O/O045.txt'),names=["G2"])

# %%
file = zipfile.ZipFile('data2.zip')
file34 = pd.read_csv(zf.open('data2/O/O046.txt'),names=["H2"])

# %%
file = zipfile.ZipFile('data2.zip')
file35 = pd.read_csv(zf.open('data2/O/O047.txt'),names=["I2"])

# %%
file = zipfile.ZipFile('data2.zip')
file36 = pd.read_csv(zf.open('data2/O/O048.txt'),names=["J2"])

# %%
file = zipfile.ZipFile('data2.zip')
file37 = pd.read_csv(zf.open('data2/O/O049.txt'),names=["K2"])

# %%
file = zipfile.ZipFile('data2.zip')
file38 = pd.read_csv(zf.open('data2/O/O050.txt'),names=["L2"])

# %%
file = zipfile.ZipFile('data2.zip')
file39 = pd.read_csv(zf.open('data2/O/O051.txt'),names=["M2"])

# %%
file = zipfile.ZipFile('data2.zip')
file40 = pd.read_csv(zf.open('data2/O/O052.txt'),names=["N2"])

# %%
file = zipfile.ZipFile('data2.zip')
file41 = pd.read_csv(zf.open('data2/O/O053.txt'),names=["O2"])

# %%
file = zipfile.ZipFile('data2.zip')
file42 = pd.read_csv(zf.open('data2/O/O054.txt'),names=["P2"])

# %%
file = zipfile.ZipFile('data2.zip')
file43 = pd.read_csv(zf.open('data2/O/O055.txt'),names=["Q2"])

# %%
file = zipfile.ZipFile('data2.zip')
file44 = pd.read_csv(zf.open('data2/O/O056.txt'),names=["R2"])

# %%
file = zipfile.ZipFile('data2.zip')
file45 = pd.read_csv(zf.open('data2/O/O057.txt'),names=["S2"])

# %%
file = zipfile.ZipFile('data2.zip')
file46 = pd.read_csv(zf.open('data2/O/O058.txt'),names=["T2"])

# %%
file = zipfile.ZipFile('data2.zip')
file47 = pd.read_csv(zf.open('data2/O/O059.txt'),names=["U2"])

# %%
file = zipfile.ZipFile('data2.zip')
file48 = pd.read_csv(zf.open('data2/O/O060.txt'),names=["V2"])

# %%
file = zipfile.ZipFile('data2.zip')
file49 = pd.read_csv(zf.open('data2/O/O061.txt'),names=["W2"])

# %%
file = zipfile.ZipFile('data2.zip')
file50 = pd.read_csv(zf.open('data2/O/O062.txt'),names=["X2"])

# %%
file = zipfile.ZipFile('data2.zip')
file51 = pd.read_csv(zf.open('data2/O/O063.txt'),names=["Y2"])

# %%
file = zipfile.ZipFile('data2.zip')
file52 = pd.read_csv(zf.open('data2/O/O064.txt'),names=["Z2"])

# %%
file = zipfile.ZipFile('data2.zip')
file2 = pd.read_csv(zf.open('data2/O/O065.txt'),names=["A3"])

# %%
file = zipfile.ZipFile('data2.zip')
file53 = pd.read_csv(zf.open('data2/O/O066.txt'),names=["B3"])

# %%
file = zipfile.ZipFile('data2.zip')
file54 = pd.read_csv(zf.open('data2/O/O067.txt'),names=["C3"])

# %%
file = zipfile.ZipFile('data2.zip')
file55 = pd.read_csv(zf.open('data2/O/O068.txt'),names=["D3"])

# %%
file = zipfile.ZipFile('data2.zip')
file56 = pd.read_csv(zf.open('data2/O/O069.txt'),names=["E3"])

# %%
file = zipfile.ZipFile('data2.zip')
file57 = pd.read_csv(zf.open('data2/O/O070.txt'),names=["F3"])

# %%
file = zipfile.ZipFile('data2.zip')
file58 = pd.read_csv(zf.open('data2/O/O071.txt'),names=["G3"])

# %%
file = zipfile.ZipFile('data2.zip')
file59 = pd.read_csv(zf.open('data2/O/O072.txt'),names=["H3"])

# %%
file = zipfile.ZipFile('data2.zip')
file60 = pd.read_csv(zf.open('data2/O/O073.txt'),names=["I3"])

# %%
file = zipfile.ZipFile('data2.zip')
file61 = pd.read_csv(zf.open('data2/O/O074.txt'),names=["J3"])

# %%
file = zipfile.ZipFile('data2.zip')
file62 = pd.read_csv(zf.open('data2/O/O075.txt'),names=["K3"])

# %%
file = zipfile.ZipFile('data2.zip')
file63 = pd.read_csv(zf.open('data2/O/O076.txt'),names=["L3"])

# %%
file = zipfile.ZipFile('data2.zip')
file64 = pd.read_csv(zf.open('data2/O/O077.txt'),names=["M3"])

# %%
file = zipfile.ZipFile('data2.zip')
file65 = pd.read_csv(zf.open('data2/O/O078.txt'),names=["N3"])

# %%
file = zipfile.ZipFile('data2.zip')
file66 = pd.read_csv(zf.open('data2/O/O079.txt'),names=["O3"])

# %%
file = zipfile.ZipFile('data2.zip')
file67 = pd.read_csv(zf.open('data2/O/O080.txt'),names=["P3"])

# %%
file = zipfile.ZipFile('data2.zip')
file68 = pd.read_csv(zf.open('data2/O/O081.txt'),names=["Q3"])

# %%
file = zipfile.ZipFile('data2.zip')
file69 = pd.read_csv(zf.open('data2/O/O082.txt'),names=["R3"])

# %%
file = zipfile.ZipFile('data2.zip')
file70 = pd.read_csv(zf.open('data2/O/O083.txt'),names=["S3"])

# %%
file = zipfile.ZipFile('data2.zip')
file71 = pd.read_csv(zf.open('data2/O/O084.txt'),names=["T3"])

# %%
file = zipfile.ZipFile('data2.zip')
file72 = pd.read_csv(zf.open('data2/O/O085.txt'),names=["U3"])

# %%
file = zipfile.ZipFile('data2.zip')
file73 = pd.read_csv(zf.open('data2/O/O086.txt'),names=["V3"])

# %%
file = zipfile.ZipFile('data2.zip')
file74 = pd.read_csv(zf.open('data2/O/O087.txt'),names=["W3"])

# %%
file = zipfile.ZipFile('data2.zip')
file75 = pd.read_csv(zf.open('data2/O/O088.txt'),names=["X3"])

# %%
file = zipfile.ZipFile('data2.zip')
file76 = pd.read_csv(zf.open('data2/O/O089.txt'),names=["Y3"])

# %%
file = zipfile.ZipFile('data2.zip')
file77 = pd.read_csv(zf.open('data2/O/O090.txt'),names=["Z3"])

# %%
file = zipfile.ZipFile('data2.zip')
file78 = pd.read_csv(zf.open('data2/O/O091.txt'),names=["A4"])

# %%
file = zipfile.ZipFile('data2.zip')
file79 = pd.read_csv(zf.open('data2/O/O092.txt'),names=["B4"])

# %%
file = zipfile.ZipFile('data2.zip')
file80 = pd.read_csv(zf.open('data2/O/O093.txt'),names=["C4"])

# %%
file = zipfile.ZipFile('data2.zip')
file81 = pd.read_csv(zf.open('data2/O/O094.txt'),names=["D4"])

# %%
file = zipfile.ZipFile('data2.zip')
file82 = pd.read_csv(zf.open('data2/O/O095.txt'),names=["E4"])

# %%
file = zipfile.ZipFile('data2.zip')
file83 = pd.read_csv(zf.open('data2/O/O096.txt'),names=["F4"])

# %%
file = zipfile.ZipFile('data2.zip')
file84 = pd.read_csv(zf.open('data2/O/O097.txt'),names=["G4"])

# %%
file = zipfile.ZipFile('data2.zip')
file85 = pd.read_csv(zf.open('data2/O/O098.txt'),names=["H4"])

# %%
file = zipfile.ZipFile('data2.zip')
file86 = pd.read_csv(zf.open('data2/O/O099.txt'),names=["I4"])

# %%
file = zipfile.ZipFile('data2.zip')
file87 = pd.read_csv(zf.open('data2/O/O100.txt'),names=["J4"])

# %% [markdown]
# ## Convert txt File to a Data Frame

# %%
txt_concat2=pd.concat([file1,file2,file3,file4,file5,file6,file7,file8,file9,file10,file11,file12,file13,file14,file15,file16,file17,file18,file19,file20,file21,file22,file23,file24,file25,file26,file27,file28,file29,file30,file31,file32,file33,file34,file35,file36,file37,file38,file39,file40,file41,file42,file43,file44,file45,file46,file47,file48,file49,file50,file51,file52,file53,file54,file55,file56,file57,file58,file59,file60,file61,file62,file63,file64,file65,file66,file67,file68,file69,file70,file71,file72,file73,file74,file75,file76,file78,file79,file80,file81,file82,file83,file84,file85,file86,file87],axis=1)
txt_concat2
# Out:
#         A    B   C   D    E   F   G    H   I    J  ...  A4   B4   C4   D4  E4  \
# 0    -159   18 -69  29  142  41 -43   71  14  -27  ...  62 -128  -83   98 -53
# 1    -176   14 -80  20  142  31 -30   82   3  -14  ...  49 -158 -120  178 -33
# 2    -174   13 -81  -8  138  28  -4   62 -14   -4  ...  14 -161 -123  236 -23
# 3    -145    9 -77 -39  143  42  29   23 -27    7  ... -14 -158 -119  237   0
# 4    -101   -6 -59 -74  130  61  41  -24 -45   21  ... -14 -152  -93  187  10
# ...   ...  ...  ..  ..  ...  ..  ..  ...  ..  ...  ...  ..  ...  ...  ...  ..
# 4092  -62   96  44  71   67  -8  13  -94 -63    0  ... -33  -20   -3  -21  94
# 4093 -100  102  47  64   92  -1  16 -130 -72   14  ... -39  -45   -5  -10  80
# 4094 -108   65  46  55   95  11  -1 -113 -68    8  ... -34  -79  -27    0  53
# 4095  -97    7  38  33   66  24   6  -55 -61   -2  ... -24  -95  -50  -12  39
# 4096 -110   45 -43 -73  142  52  12    8 -27 -137  ...  95   46  -38  -16  72
#
#        F4   G4  H4  I4  J4
# ...

# %%
dataset2=pd.DataFrame(txt_concat2)
dataset2
# Out:
#         A    B   C   D    E   F   G    H   I    J  ...  A4   B4   C4   D4  E4  \
# 0    -159   18 -69  29  142  41 -43   71  14  -27  ...  62 -128  -83   98 -53
# 1    -176   14 -80  20  142  31 -30   82   3  -14  ...  49 -158 -120  178 -33
# 2    -174   13 -81  -8  138  28  -4   62 -14   -4  ...  14 -161 -123  236 -23
# 3    -145    9 -77 -39  143  42  29   23 -27    7  ... -14 -158 -119  237   0
# 4    -101   -6 -59 -74  130  61  41  -24 -45   21  ... -14 -152  -93  187  10
# ...   ...  ...  ..  ..  ...  ..  ..  ...  ..  ...  ...  ..  ...  ...  ...  ..
# 4092  -62   96  44  71   67  -8  13  -94 -63    0  ... -33  -20   -3  -21  94
# 4093 -100  102  47  64   92  -1  16 -130 -72   14  ... -39  -45   -5  -10  80
# 4094 -108   65  46  55   95  11  -1 -113 -68    8  ... -34  -79  -27    0  53
# 4095  -97    7  38  33   66  24   6  -55 -61   -2  ... -24  -95  -50  -12  39
# 4096 -110   45 -43 -73  142  52  12    8 -27 -137  ...  95   46  -38  -16  72
#
#        F4   G4  H4  I4  J4
# ...

# %%
dataset1
# Out:
#         A    B    C    D    E    F    G    H    I    J  ...   Z3   A4   B4  \
# 0     100  340 -310   84  343  -88  176  661 -377   23  ...  134 -129  -26
# 1     124  353   93   75  311 -115  186  721 -379  144  ...  390 -309    1
# 2     153  400  494   21  284 -140  189  702 -396  228  ...  446 -432   29
# 3     185  470  789  -68  274 -159  198  628 -448  260  ...  329 -412   41
# 4     210  538  798 -138  260 -164  205  519 -476  255  ...   49 -278   33
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4092    7  829 -735 -234  515  153  100    7  -93 -272  ... -104  -44 -205
# 4093   26  722 -847 -238  527  150   98    5  -82 -272  ... -189   95 -209
# 4094   57  512 -721 -209  480  146  101   12  -89 -155  ... -153   12 -207
# 4095   95  130 -491 -165  397  140   99   29 -132    6  ...  -62 -254 -210
# 4096  462  196  910 -212  217  191 -554 -211 -279 -221  ...   72  -57 -107
#
#         C4   D4   E4   F4   G4   H4   I4
# ...

# %%
dataset2
# Out:
#         A    B   C   D    E   F   G    H   I    J  ...  A4   B4   C4   D4  E4  \
# 0    -159   18 -69  29  142  41 -43   71  14  -27  ...  62 -128  -83   98 -53
# 1    -176   14 -80  20  142  31 -30   82   3  -14  ...  49 -158 -120  178 -33
# 2    -174   13 -81  -8  138  28  -4   62 -14   -4  ...  14 -161 -123  236 -23
# 3    -145    9 -77 -39  143  42  29   23 -27    7  ... -14 -158 -119  237   0
# 4    -101   -6 -59 -74  130  61  41  -24 -45   21  ... -14 -152  -93  187  10
# ...   ...  ...  ..  ..  ...  ..  ..  ...  ..  ...  ...  ..  ...  ...  ...  ..
# 4092  -62   96  44  71   67  -8  13  -94 -63    0  ... -33  -20   -3  -21  94
# 4093 -100  102  47  64   92  -1  16 -130 -72   14  ... -39  -45   -5  -10  80
# 4094 -108   65  46  55   95  11  -1 -113 -68    8  ... -34  -79  -27    0  53
# 4095  -97    7  38  33   66  24   6  -55 -61   -2  ... -24  -95  -50  -12  39
# 4096 -110   45 -43 -73  142  52  12    8 -27 -137  ...  95   46  -38  -16  72
#
#        F4   G4  H4  I4  J4
# ...

# %% [markdown]
# ## Marging All Data Frame
# Now Our Main DataFrame is Main_dataset

# %%
main_dataset= pd.concat([dataset1,dataset2],axis=1)
main_dataset
# Out:
#         A    B    C    D    E    F    G    H    I    J  ...  A4   B4   C4  \
# 0     100  340 -310   84  343  -88  176  661 -377   23  ...  62 -128  -83
# 1     124  353   93   75  311 -115  186  721 -379  144  ...  49 -158 -120
# 2     153  400  494   21  284 -140  189  702 -396  228  ...  14 -161 -123
# 3     185  470  789  -68  274 -159  198  628 -448  260  ... -14 -158 -119
# 4     210  538  798 -138  260 -164  205  519 -476  255  ... -14 -152  -93
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ..  ...  ...
# 4092    7  829 -735 -234  515  153  100    7  -93 -272  ... -33  -20   -3
# 4093   26  722 -847 -238  527  150   98    5  -82 -272  ... -39  -45   -5
# 4094   57  512 -721 -209  480  146  101   12  -89 -155  ... -34  -79  -27
# 4095   95  130 -491 -165  397  140   99   29 -132    6  ... -24  -95  -50
# 4096  462  196  910 -212  217  191 -554 -211 -279 -221  ...  95   46  -38
#
#        D4  E4   F4   G4  H4  I4  J4
# 0      98 -53   29  -76  27  -6 -18
# ...

# %%
main_dataset.describe()
# Out:
#                  A            B            C            D            E  \
# count  4097.000000  4097.000000  4097.000000  4097.000000  4097.000000
# mean     47.100073    37.571882    30.493532     7.087137    12.870393
# std     478.543252   505.122579   374.122833   159.852584   332.495998
# min   -1765.000000 -1816.000000 -1283.000000  -399.000000 -1026.000000
# 25%    -135.000000  -269.000000  -145.000000  -111.000000  -250.000000
# 50%     187.000000   116.000000    83.000000    10.000000    83.000000
# 75%     369.000000   406.000000   260.000000   114.000000   283.000000
# max    1027.000000  1364.000000  1435.000000   467.000000   727.000000
#
#                  F            G            H            I            J  ...  \
# count  4097.000000  4097.000000  4097.000000  4097.000000  4097.000000  ...
# mean     -5.800830     9.450085   -50.364901   -33.471565     3.282158  ...
# std     126.235489   248.512160   404.946030   332.302713   259.287938  ...
# ...

# %%
main_dataset.isnull().sum()
# Out:
# A     0
# B     0
# C     0
# D     0
# E     0
#      ..
# F4    0
# G4    0
# H4    0
# I4    0
# J4    0
# Length: 174, dtype: int64

# %%
main_dataset.corr()
# Out:
#            A         B         C         D         E         F         G  \
# A   1.000000 -0.011961 -0.009310 -0.024849  0.007771  0.000572 -0.013636
# B  -0.011961  1.000000  0.007620  0.027045  0.040234 -0.035052 -0.023047
# C  -0.009310  0.007620  1.000000 -0.016573  0.008622 -0.001328  0.009514
# D  -0.024849  0.027045 -0.016573  1.000000  0.002062 -0.037684  0.014287
# E   0.007771  0.040234  0.008622  0.002062  1.000000  0.029874  0.022464
# ..       ...       ...       ...       ...       ...       ...       ...
# F4 -0.089841  0.028885  0.006266  0.064951  0.019212  0.020087 -0.021536
# G4 -0.025614 -0.009657  0.030604 -0.028421 -0.016126  0.013272 -0.037051
# H4  0.026284  0.003537 -0.009559  0.016771  0.026612 -0.021983  0.002617
# I4  0.011563 -0.014928 -0.016870 -0.020269  0.050556  0.019140 -0.037119
# J4 -0.027779  0.036972  0.018397 -0.035017  0.043666 -0.025092  0.001973
#
#            H         I         J  ...        A4        B4        C4        D4  \
# ...

# %% [markdown]
# ## Now Here We Perform K-means Clustering Algorithm for Knowing Target Variable and Understanding Much Better Way

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++',
                    random_state = 0)
    kmeans.fit(main_dataset)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 2, init = 'k-means++', 
                random_state = 0)
y_kmeans = kmeans.fit_predict(main_dataset)

# %%
b=y_kmeans

# %%
main_dataset["target"]=b

# %%
main_dataset
# Out:
#         A    B    C    D    E    F    G    H    I    J  ...   B4   C4   D4  \
# 0     100  340 -310   84  343  -88  176  661 -377   23  ... -128  -83   98
# 1     124  353   93   75  311 -115  186  721 -379  144  ... -158 -120  178
# 2     153  400  494   21  284 -140  189  702 -396  228  ... -161 -123  236
# 3     185  470  789  -68  274 -159  198  628 -448  260  ... -158 -119  237
# 4     210  538  798 -138  260 -164  205  519 -476  255  ... -152  -93  187
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4092    7  829 -735 -234  515  153  100    7  -93 -272  ...  -20   -3  -21
# 4093   26  722 -847 -238  527  150   98    5  -82 -272  ...  -45   -5  -10
# 4094   57  512 -721 -209  480  146  101   12  -89 -155  ...  -79  -27    0
# 4095   95  130 -491 -165  397  140   99   29 -132    6  ...  -95  -50  -12
# 4096  462  196  910 -212  217  191 -554 -211 -279 -221  ...   46  -38  -16
#
#       E4   F4   G4  H4  I4  J4  target
# ...

# %%
main_dataset["target"].value_counts()
# Out:
# 0    2740
# 1    1357
# Name: target, dtype: int64

# %%
main_dataset.isnull().sum()
# Out:
# A         0
# B         0
# C         0
# D         0
# E         0
#          ..
# G4        0
# H4        0
# I4        0
# J4        0
# target    0
# Length: 175, dtype: int64

# %%
main_dataset.corr()
# Out:
#                A         B         C         D         E         F         G  \
# A       1.000000 -0.011961 -0.009310 -0.024849  0.007771  0.000572 -0.013636
# B      -0.011961  1.000000  0.007620  0.027045  0.040234 -0.035052 -0.023047
# C      -0.009310  0.007620  1.000000 -0.016573  0.008622 -0.001328  0.009514
# D      -0.024849  0.027045 -0.016573  1.000000  0.002062 -0.037684  0.014287
# E       0.007771  0.040234  0.008622  0.002062  1.000000  0.029874  0.022464
# ...          ...       ...       ...       ...       ...       ...       ...
# G4     -0.025614 -0.009657  0.030604 -0.028421 -0.016126  0.013272 -0.037051
# H4      0.026284  0.003537 -0.009559  0.016771  0.026612 -0.021983  0.002617
# I4      0.011563 -0.014928 -0.016870 -0.020269  0.050556  0.019140 -0.037119
# J4     -0.027779  0.036972  0.018397 -0.035017  0.043666 -0.025092  0.001973
# target  0.015239  0.033584  0.005335 -0.495106 -0.015280  0.037306  0.006963
#
# ...

# %%
sns.countplot(x="target",data=main_dataset)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
plt.figure(figsize=(16,11))
sns.heatmap(main_dataset)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(main_dataset.corr(),annot=True,cmap="viridis")
plt.show()

# %% [markdown]
# ## Correlation barplot
# Taking the correlation of each feature with the target and the visualize barplot.

# %%
dataset2=main_dataset.drop("target",axis=1)
plt.figure(figsize = (16,8))
result=sns.barplot(dataset2.corrwith(main_dataset.target).index,dataset2.corrwith(main_dataset.target))
result.tick_params(labelrotation = 90)

# %% [markdown]
# ## In the above correlation barplot So many features are strongly positively correlated with the target than others. And some features are very less positive correlated and others remaining are strongly negatively correlated.

# %% [markdown]
# ## Data Preprocessing
# Split DataFrame in train and test

# %%
x = main_dataset.drop("target",axis=1)
x.head(3)
# Out:
#      A    B    C   D    E    F    G    H    I    J  ...  A4   B4   C4   D4  \
# 0  100  340 -310  84  343  -88  176  661 -377   23  ...  62 -128  -83   98
# 1  124  353   93  75  311 -115  186  721 -379  144  ...  49 -158 -120  178
# 2  153  400  494  21  284 -140  189  702 -396  228  ...  14 -161 -123  236
#
#    E4  F4   G4  H4  I4  J4
# 0 -53  29  -76  27  -6 -18
# 1 -33  10 -102   4 -19 -13
# 2 -23 -26  -95   1 -47   0
#
# [3 rows x 174 columns]

# %%
y = main_dataset["target"]
y.head(3)
# Out:
# 0    0
# 1    1
# 2    1
# Name: target, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Feature Scaling
# Converting different units and magnitude data in one unit.

# %%
from sklearn.preprocessing import StandardScaler
scaling = StandardScaler()
x_train_scaling_data = scaling.fit_transform(x_train)
x_test_scaling_data = scaling.transform(x_test)

# %% [markdown]
# ## Machine Learning Model Building
# We have clean data to build the Ml model. But which Machine learning algorithm is best for the data we have to find. The output is a categorical format so we will use supervised classification machine learning algorithms.
#
# To build the best model, we have to train and test the dataset with multiple Machine Learning algorithms then we can find the best ML model. So let’s try.
#
# First, we need to import the required packages.

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ## Trained  Model with out Standard Scaled Data

# %%
# Trained with out Standard Scaled Data

from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression()
logistic_model.fit(x_train,y_train)
y_pred_logistic_model = logistic_model.predict(x_test)
accuracy_score(y_pred_logistic_model,y_test)
# Out:
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9890243902439024

# %%
logistic_model.score(x_train,y_train)
# Out:
# 1.0

# %%
logistic_model.score(x_test,y_test)
# Out:
# 0.9890243902439024

# %% [markdown]
# ## So Our Logistic Regression With Out Trained Standard Scale Data  Model gives us 100 % Accuracy in our Training Data and gives 98.90% Accuracy in our Testing Data

# %% [markdown]
# ## Now Trained Model with Standard Scaled Data

# %%
# Trained with Standard Scaled Data

logistic_model2 = LogisticRegression()
logistic_model2.fit(x_train_scaling_data,y_train)
y_pred_logistic_model2 = logistic_model2.predict(x_test_scaling_data)
accuracy_score(y_test,y_pred_logistic_model2)
# Out:
# 0.9829268292682927

# %%
logistic_model2.score(x_train_scaling_data,y_train)
# Out:
# 1.0

# %%
logistic_model2.score(x_test_scaling_data,y_test)
# Out:
# 0.9829268292682927

# %% [markdown]
# ## So Our Logistic Regression With Trained Standard Scale Data Model gives us 100 % Accuracy in our Training Data and gives 98.29% Accuracy in our Testing Data

# %%
y_pred = logistic_model.predict(x_test)
Accuracy= confusion_matrix(y_test,y_pred)
Accuracy
# Out:
# array([[545,   6],
#        [  3, 266]], dtype=int64)

# %%
cm = confusion_matrix(y_test,y_pred)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sns.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# ## Random Forest Classifier

# %% [markdown]
# ## Trained Model with out Standard Scaled Data

# %%
# Trained with out Standard Scaled Data

from sklearn.ensemble import RandomForestClassifier
random_forest_model = RandomForestClassifier(n_estimators= 20,criterion= 'entropy',random_state=42)
random_forest_model.fit(x_train,y_train)
y_pred_random_forest_model = random_forest_model.predict(x_test)
accuracy_score(y_pred_random_forest_model ,y_test)
# Out:
# 0.9902439024390244

# %%
random_forest_model.score(x_train,y_train)
# Out:
# 1.0

# %%
random_forest_model.score(x_test,y_test)
# Out:
# 0.9902439024390244

# %% [markdown]
# ## So Our Random Forest Classifier With Out Trained Standard Scale Data Model gives us 100 % Accuracy in our Training Data and gives 99.02% Accuracy in our Testing Data

# %% [markdown]
# ## Now Trained Model with Standard Scaled Data

# %%
# Trained with Standard Scaled Data

random_forest_model2 = RandomForestClassifier(n_estimators= 20,criterion='entropy',random_state=42)
random_forest_model2.fit(x_train_scaling_data,y_train)
y_pred_random_forest_model2 = random_forest_model2.predict(x_test_scaling_data)
accuracy_score(y_test,y_pred_random_forest_model2)
# Out:
# 0.9902439024390244

# %%
random_forest_model2.score(x_train_scaling_data,y_train)
# Out:
# 1.0

# %%
random_forest_model2.score(x_test_scaling_data,y_test)
# Out:
# 0.9902439024390244

# %% [markdown]
# ## So Our Random Forest Classifier With Out Trained Standard Scale Data Model gives us  100 % Accuracy in our Training Data and gives 99.02% Accuracy in our Testing Data

# %%
prediction = random_forest_model.predict(x_test)
Accuracy= confusion_matrix(y_test,prediction)
Accuracy
# Out:
# array([[549,   2],
#        [  6, 263]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       551
#            1       0.99      0.98      0.99       269
#
#     accuracy                           0.99       820
#    macro avg       0.99      0.99      0.99       820
# weighted avg       0.99      0.99      0.99       820

# %%
cm = confusion_matrix(y_test,prediction)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sns.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# ## So Finally This  Machine learning Model successfully  Completed with 99.02% accuracy which is great.
